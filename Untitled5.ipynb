# %% [markdown]
# <a href="https://colab.research.google.com/github/Durgakesav/Durgakesav.github.io/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import random
import numpy as np

x = np.array([i+1 for i in range(20)])
y = np.array([(50 * x[i]) + random.randrange(-100, 100) for i in range(20)])

plt.scatter(x, y, marker='o')

xbar = np.mean(x)
ybar = np.mean(y)

numerator = 0
denominator = 0
for i in range(20):
    numerator += (x[i] - xbar) * (y[i] - ybar)
    denominator += (x[i] - xbar) ** 2

beta1 = numerator / denominator
beta0 = ybar - beta1 * xbar

y_pred = beta0 + beta1 * x

plt.plot(x, y_pred, color='red', label='Regression Line')
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Scatter Plot with Regression Line")
plt.legend()
plt.show()

residuals = y - y_pred
mse = np.mean(residuals ** 2)
mae = np.mean(np.abs(residuals))
rmse = np.sqrt(mse)

print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Residuals: {residuals}")
# Out:
# Mean Squared Error (MSE): 2613.938270676693
# Mean Absolute Error (MAE): 46.24383458646617
# Root Mean Squared Error (RMSE): 51.1266884383948
# Residuals: [ 60.15714286  16.58270677 -45.99172932 -17.56616541 -39.1406015
#  -45.71503759 -17.28947368 -24.86390977  83.56165414  43.98721805
#   49.41278195 -76.16165414  31.26390977 -68.31052632  58.11503759
#   68.5406015  -78.03383459  -6.60827068  50.81729323 -42.75714286]
